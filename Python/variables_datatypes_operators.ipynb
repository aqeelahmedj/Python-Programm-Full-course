# %% [markdown]
# # Variables, DataTypes and Operators in Python

# %% [markdown]
# Let us now discuss about the most importatnt topics to understand as a beginner..!
#
# You may have heared different definitions of the variable. But I will tell the simplest definiton.
#
# A variable is a memory space represented by some characters to store some value but not permanently.
# so variable means changeable.. you can create variables yourself...
#
# a variable can store different datatypes depending upon your choice.
# You cannot create variables of keywords in python. As python will understand that
# you have decalared a keyword which is already fixed for Python.... hence avoid that..!
#
# -DataType: Python has various datatypes like other programming languages. i.e integer, float, double and char, etc
#
# - Numbers
# - String
# - Tuples
# - List
# - Dictionary

# %%
#Let us start with declaring and assining values to a variable

Class = 14    #here class is name of variable which will store 14 which is an integer 

City = 'Karachi' #here city is a variable which will store karachi (char type dataype)

Pii = 3.143 # so Pi might be keyword which already but here I define Pii which store decimal value (float )

maths_101 = 'subject code'  # a number cannot be individually a variable.. but it can be with string

# %%
#ok let us see another example...

prgramig_languages= "python", "Java", "C++", "Rust"

#so what kind of datatype is this? you can simply print the type of this variable. 

print(type(prgramig_languages))
# Out:
# <class 'tuple'>

# %% [markdown]
# so...! its class tuple.. tuple is another datatype which stores values in a sequence form.
# it is a very useful datatype. we will play with tuples in our next codes.
#
# usually tuple is represented is small brackets ().
#
# Remember a tuple is immutable.....?.. immutable--->not changeable..! yes, you cannot change a tuple..!

# %%
# ok let us see another datatype in python.

listA= ['Ali','Ahmed','waqar','Khalid','Jameel']
listA

#Yes..This is called a List...!
# Out:
# ['Ali', 'Ahmed', 'waqar', 'Khalid', 'Jameel']

# %% [markdown]
# - List
# Like tuple, a list is also a built-in data structure available in Python.
# It can contain heterogeneous values such as integers, floats, strings,
# tuples, lists, and dictionaries.  However, Python lists are mutable; yes, they can change.

# %% [markdown]
# - Dictionary
#
# In Python, a dictionary is a sequence of key-value, or item, pairs separated by commas.
# Consider the following example:
# The syntax of a dictionary is as follows:
#
# Dictionary_name = {key: value}
#
# - The key of the dictionary can not be changed
# - A string, int, or float can be used as a key
# - A tuple that does not contain any list can be used as a key
# - Keys are unique
# - Values can be anything, for example, list, string, int, and so on
# - Values can be repeated
# - Values can be changed
# - A dictionary is an unordered collection, which means that the order in which you
# - have entered the items in a dictionary may not be retained and you may get the items in a different orde

# %%
port = {22: "SSH", 23: "Telnet" , 53: "DNS", 80: "HTTP" }
port

#The port variable refers to a dictionary that contains port numbers as keys and its protocol names as values
# Out:
# {22: 'SSH', 23: 'Telnet', 53: 'DNS', 80: 'HTTP'}

# %% [markdown]
# # MATH OPERATORS

# %%
#Addition : a + b 

Sum = 10 + 40 
print("Sum :", Sum)

#Subtraction: a- b

Sub = 40-10
print("Sub :", Sub)

#Mult : a * b 
 
Mult = 10*30
print("Mult:", Mult)
    
#Division a / b

Div = 40 /10
print("div :",Div)

# Reminder a % b 

Rem = 40 % 2 
print("Rem :", Rem)

#Exponention 

Exp =  2**3
print("Exponent: ", Exp)
# Out:
# Sum : 50
# Sub : 30
# Mult: 300
# div : 4.0
# Rem : 0
# Exponent:  8

# %% [markdown]
# # COMAPRISON OPERATOR

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#Practice 
a = 30
b = 20

A= a==b
print(A)
B =a < b
print(B)
C =a > b
print(C)
D=a <=b
print(D)
E=a>=b
print(E)
F=a!=b
print(F)
# Out:
# False
# False
# True
# False
# True
# True

# %% [markdown]
# # Variant Assignment Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SUMMARY OF ALL OPERATORS

# %% [markdown]
# ![image.png](attachment:image.png)
